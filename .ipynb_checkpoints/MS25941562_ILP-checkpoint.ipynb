# %% [markdown]
# # CVRP Optimization: Exact Method (ILP)

# %% [markdown]
# ## Mathematical Formulation

# %% [markdown]
# * **Decision Variables:** * $x_{ij} \in \{0, 1\}$: $1$ if a vehicle travels from node $i$ to $j$.
#   * $u_i$: Auxiliary variable for capacity/sub-tour tracking.
# * **Objective:**
#   * Minimize $Z = \sum_{i} \sum_{j} c_{ij} x_{ij}$ (Total distance).
# * **Constraints:**
#   1. Every customer must be visited exactly once.
#   2. Vehicles must return to the depot.
#   3. **Capacity Constraint:** Total demand on a route $\le$ Vehicle Capacity $Q$.

# %% [markdown]
# ## Data Parsing Component

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/dxdy/Library/Python/3.9/lib/python/site-packages (from scipy) (2.0.2)
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 242.6 kB/s  0:02:05m0:00:0100:04
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
# !pip install pulp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pulp
#   Downloading pulp-3.3.0-py3-none-any.whl.metadata (8.4 kB)
# Downloading pulp-3.3.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 241.9 kB/s  0:01:08m0:00:0100:03
# Installing collected packages: pulp
# Successfully installed pulp-3.3.0
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance_matrix
import pulp

def load_vrp_data(filepath):
    """Parses the .vrp file to extract nodes, demands, and capacity."""
    with open(filepath, 'r') as f:
        lines = f.readlines()

    capacity = int([l for l in lines if "CAPACITY" in l][0].split(":")[1])
    
    # Find start of sections
    coord_start = lines.index("NODE_COORD_SECTION\t\t\n") + 1
    demand_start = lines.index("DEMAND_SECTION\t\t\n") + 1
    dimension = int([l for l in lines if "DIMENSION" in l][0].split(":")[1])

    # Parse Coordinates
    coords = []
    for i in range(coord_start, coord_start + dimension):
        parts = lines[i].split()
        coords.append((float(parts[1]), float(parts[2])))

    # Parse Demands
    demands = []
    for i in range(demand_start, demand_start + dimension):
        demands.append(int(lines[i].split()[1]))

    return np.array(coords), demands, capacity

# Load your specific Kaggle files
all_coords, all_demands, capacity = load_vrp_data('data/X-n101-k25.vrp')

# Select the subset (First 20 nodes for the Exact Method test)
N_SUBSET = 20
coords = all_coords[:N_SUBSET]
demands = all_demands[:N_SUBSET]
dist_mat = distance_matrix(coords, coords)
N = len(coords)

# %% [markdown]
# ## ILP Model Implementation

# %%
# 1. Initialize Problem
prob = pulp.LpProblem("CVRP_Exact_ILP", pulp.LpMinimize)

# 2. Decision Variables
x = pulp.LpVariable.dicts("x", [(i, j) for i in range(N) for j in range(N)], cat='Binary')
u = pulp.LpVariable.dicts("u", range(N), lowBound=0, upBound=capacity)

# 3. Objective Function: Minimize Total Distance
prob += pulp.lpSum(dist_mat[i][j] * x[i, j] for i in range(N) for j in range(N) if i != j)

# 4. Constraints
for i in range(N):
    # Every customer visited once
    prob += pulp.lpSum(x[j, i] for j in range(N) if i != j) == 1
    prob += pulp.lpSum(x[i, j] for j in range(N) if i != j) == 1

# Sub-tour elimination & Capacity (MTZ Formulation)
for i in range(1, N):
    for j in range(1, N):
        if i != j:
            prob += u[i] - u[j] + capacity * x[i, j] <= capacity - demands[j]

for i in range(1, N):
    prob += u[i] >= demands[i]

# 5. Solver with 15-minute time limit (as the problem is NP-Hard)
solver = pulp.PULP_CBC_CMD(timeLimit=900, msg=1)
prob.solve(solver)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/dxdy/Library/Python/3.9/lib/python/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/ml/czjfmszj3r3125pzm_gw9mdc0000gn/T/51b8bbd82b2b45a39c3bc1aab0def607-pulp.mps -sec 900 -timeMode elapsed -branch -printingOptions all -solution /var/folders/ml/czjfmszj3r3125pzm_gw9mdc0000gn/T/51b8bbd82b2b45a39c3bc1aab0def607-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10207 COLUMNS
# At line 90508 RHS
# At line 100711 BOUNDS
# At line 110912 ENDATA
# Problem MODEL has 10202 rows, 10200 columns and 50000 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 900
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6502.05 - 0.03 seconds
# Cgl0004I processed model has 10102 rows, 10200 columns (10100 integer (10100 of which binary)) and 49900 elements
# Cbc0038I Initial state - 237 integers unsatisfied sum - 69.0437
# Cbc0038I Pass   1: (0.39 seconds) suminf.   42.34093 (161) obj. 20186.4 iterations 1009
# Cbc0038I Pass   2: (0.54 seconds) suminf.   38.03883 (169) obj. 23069.8 iterations 671
# Cbc0038I Pass   3: (0.57 seconds) suminf.   38.03883 (174) obj. 23159.4 iterations 76
# Cbc0038I Pass   4: (0.70 seconds) suminf.   36.76893 (176) obj. 24564.5 iterations 599
# Cbc0038I Pass   5: (0.76 seconds) suminf.   36.27184 (174) obj. 24707.3 iterations 202
# Cbc0038I Pass   6: (0.90 seconds) suminf.   35.00971 (199) obj. 24829.9 iterations 630
# Cbc0038I Pass   7: (1.05 seconds) suminf.   34.61165 (220) obj. 25392.6 iterations 668
# Cbc0038I Pass   8: (1.22 seconds) suminf.   36.51036 (190) obj. 26105.7 iterations 689
# Cbc0038I Pass   9: (1.35 seconds) suminf.   34.43787 (203) obj. 26615.7 iterations 559
# Cbc0038I Pass  10: (1.41 seconds) suminf.   34.19417 (213) obj. 26293.3 iterations 204
# Cbc0038I Pass  11: (1.66 seconds) suminf.   33.63035 (230) obj. 26409.7 iterations 1038
# Cbc0038I Pass  12: (1.73 seconds) suminf.   32.99029 (248) obj. 26878.4 iterations 244
# Cbc0038I Pass  13: (1.97 seconds) suminf.   35.46569 (203) obj. 28303.6 iterations 1045
# Cbc0038I Pass  14: (2.12 seconds) suminf.   33.13801 (238) obj. 27953.6 iterations 583
# Cbc0038I Pass  15: (2.20 seconds) suminf.   32.44660 (253) obj. 28091 iterations 292
# Cbc0038I Pass  16: (2.41 seconds) suminf.   33.37736 (222) obj. 27275.8 iterations 812
# Cbc0038I Pass  17: (2.51 seconds) suminf.   32.35219 (232) obj. 27306.6 iterations 399
# Cbc0038I Pass  18: (2.59 seconds) suminf.   31.55340 (257) obj. 27758.7 iterations 315
# Cbc0038I Pass  19: (2.80 seconds) suminf.   34.98829 (203) obj. 28009.5 iterations 901
# Cbc0038I Pass  20: (2.95 seconds) suminf.   32.42718 (248) obj. 27832.6 iterations 653
# Cbc0038I Pass  21: (3.11 seconds) suminf.   33.06489 (217) obj. 27810.1 iterations 625
# Cbc0038I Pass  22: (3.18 seconds) suminf.   32.62136 (227) obj. 27975.7 iterations 224
# Cbc0038I Pass  23: (3.36 seconds) suminf.   34.55887 (195) obj. 28073 iterations 715
# Cbc0038I Pass  24: (3.51 seconds) suminf.   32.43689 (216) obj. 28199 iterations 649
# Cbc0038I Pass  25: (3.70 seconds) suminf.   33.71845 (236) obj. 28437.6 iterations 795
# Cbc0038I Pass  26: (3.78 seconds) suminf.   33.51284 (218) obj. 27665.8 iterations 293
# Cbc0038I Pass  27: (3.86 seconds) suminf.   32.68932 (237) obj. 27645 iterations 270
# Cbc0038I Pass  28: (4.09 seconds) suminf.   33.58426 (218) obj. 29294.4 iterations 964
# Cbc0038I Pass  29: (4.23 seconds) suminf.   31.80583 (253) obj. 29123.3 iterations 537
# Cbc0038I Pass  30: (4.40 seconds) suminf.   33.56535 (205) obj. 28876.2 iterations 706
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9035 integers at bound fixed and 1 continuous
# Cbc0038I Full problem 10102 rows 10200 columns, reduced to 1208 rows 1110 columns
# Cbc0038I Mini branch and bound did not improve solution (4.44 seconds)
# Cbc0038I After 4.44 seconds - Feasibility pump exiting - took 4.25 seconds
# Cbc0031I 119 added rows had average density of 369.06723
# Cbc0013I At root node, 119 cuts changed objective from 6502.0522 to 6971.1192 in 13 passes
# Cbc0014I Cut generator 0 (Probing) - 8 row cuts average 4.2 elements, 0 column cuts (0 active)  in 0.323 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 301 row cuts average 927.7 elements, 0 column cuts (0 active)  in 0.247 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 8 row cuts average 3.2 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 495 row cuts average 21.4 elements, 0 column cuts (0 active)  in 0.095 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 106 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.152 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 679 row cuts average 89.4 elements, 0 column cuts (0 active)  in 0.194 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 6971.1192 (7.10 seconds)
# Cbc0010I After 100 nodes, 52 on tree, 1e+50 best solution, best possible 6971.1192 (22.13 seconds)
# Cbc0010I After 200 nodes, 81 on tree, 1e+50 best solution, best possible 6971.1192 (36.92 seconds)
# Cbc0010I After 300 nodes, 110 on tree, 1e+50 best solution, best possible 6971.1192 (52.11 seconds)
# Cbc0010I After 400 nodes, 139 on tree, 1e+50 best solution, best possible 6971.1192 (69.76 seconds)
# Cbc0010I After 500 nodes, 163 on tree, 1e+50 best solution, best possible 6971.1192 (89.39 seconds)
# Cbc0010I After 600 nodes, 188 on tree, 1e+50 best solution, best possible 6971.1192 (110.29 seconds)
# Cbc0010I After 700 nodes, 214 on tree, 1e+50 best solution, best possible 6971.1192 (140.56 seconds)
# Cbc0010I After 800 nodes, 234 on tree, 1e+50 best solution, best possible 6971.1192 (160.45 seconds)
# Cbc0010I After 900 nodes, 246 on tree, 1e+50 best solution, best possible 6971.1192 (184.25 seconds)
# Cbc0010I After 1000 nodes, 245 on tree, 1e+50 best solution, best possible 6971.1192 (218.66 seconds)
# Cbc0010I After 1100 nodes, 341 on tree, 1e+50 best solution, best possible 6971.1192 (230.04 seconds)
# Cbc0010I After 1200 nodes, 438 on tree, 1e+50 best solution, best possible 6971.1192 (236.41 seconds)
# Cbc0010I After 1300 nodes, 536 on tree, 1e+50 best solution, best possible 6971.1192 (241.25 seconds)
# Cbc0010I After 1400 nodes, 636 on tree, 1e+50 best solution, best possible 6971.1192 (247.40 seconds)
# Cbc0010I After 1500 nodes, 736 on tree, 1e+50 best solution, best possible 6971.1192 (253.19 seconds)
# Cbc0010I After 1600 nodes, 755 on tree, 1e+50 best solution, best possible 6971.1192 (260.73 seconds)
# Cbc0010I After 1700 nodes, 751 on tree, 1e+50 best solution, best possible 6971.1192 (270.86 seconds)
# Cbc0010I After 1800 nodes, 758 on tree, 1e+50 best solution, best possible 6971.1192 (282.02 seconds)
# Cbc0010I After 1900 nodes, 758 on tree, 1e+50 best solution, best possible 6971.1192 (291.95 seconds)
# Cbc0010I After 2000 nodes, 751 on tree, 1e+50 best solution, best possible 6971.1192 (302.84 seconds)
# Cbc0010I After 2100 nodes, 751 on tree, 1e+50 best solution, best possible 6971.1192 (312.79 seconds)
# Cbc0010I After 2200 nodes, 786 on tree, 1e+50 best solution, best possible 6971.1192 (320.11 seconds)
# Cbc0010I After 2300 nodes, 776 on tree, 1e+50 best solution, best possible 6971.1192 (329.36 seconds)
# Cbc0010I After 2400 nodes, 803 on tree, 1e+50 best solution, best possible 6971.1192 (343.38 seconds)
# Cbc0010I After 2500 nodes, 773 on tree, 1e+50 best solution, best possible 6971.1192 (357.44 seconds)
# Cbc0010I After 2600 nodes, 773 on tree, 1e+50 best solution, best possible 6971.1192 (378.21 seconds)
# Cbc0010I After 2700 nodes, 771 on tree, 1e+50 best solution, best possible 6971.1192 (400.26 seconds)
# Cbc0010I After 2800 nodes, 777 on tree, 1e+50 best solution, best possible 6971.1192 (422.17 seconds)
# Cbc0010I After 2900 nodes, 771 on tree, 1e+50 best solution, best possible 6971.1192 (441.56 seconds)
# Cbc0010I After 3000 nodes, 765 on tree, 1e+50 best solution, best possible 6971.1192 (451.02 seconds)
# Cbc0010I After 3100 nodes, 760 on tree, 1e+50 best solution, best possible 6971.1192 (463.68 seconds)
# Cbc0010I After 3200 nodes, 757 on tree, 1e+50 best solution, best possible 6971.1192 (475.91 seconds)
# Cbc0010I After 3300 nodes, 757 on tree, 1e+50 best solution, best possible 6971.1192 (490.61 seconds)
# Cbc0010I After 3400 nodes, 758 on tree, 1e+50 best solution, best possible 6971.1192 (501.53 seconds)
# Cbc0010I After 3500 nodes, 760 on tree, 1e+50 best solution, best possible 6971.1192 (515.17 seconds)
# Cbc0010I After 3600 nodes, 758 on tree, 1e+50 best solution, best possible 6971.1192 (528.36 seconds)
# Cbc0010I After 3700 nodes, 754 on tree, 1e+50 best solution, best possible 6971.1192 (539.80 seconds)
# Cbc0010I After 3800 nodes, 749 on tree, 1e+50 best solution, best possible 6971.1192 (550.42 seconds)
# Cbc0010I After 3900 nodes, 754 on tree, 1e+50 best solution, best possible 6971.1192 (560.95 seconds)
# Cbc0010I After 4000 nodes, 752 on tree, 1e+50 best solution, best possible 6971.1192 (570.15 seconds)
# Cbc0010I After 4100 nodes, 755 on tree, 1e+50 best solution, best possible 6971.1192 (580.95 seconds)
# Cbc0010I After 4200 nodes, 758 on tree, 1e+50 best solution, best possible 6971.1192 (596.06 seconds)
# Cbc0010I After 4300 nodes, 756 on tree, 1e+50 best solution, best possible 6971.1192 (618.31 seconds)
# Cbc0010I After 4400 nodes, 755 on tree, 1e+50 best solution, best possible 6971.1192 (629.04 seconds)
# Cbc0010I After 4500 nodes, 751 on tree, 1e+50 best solution, best possible 6971.1192 (639.70 seconds)
# Cbc0010I After 4600 nodes, 753 on tree, 1e+50 best solution, best possible 6971.1192 (649.02 seconds)
# Cbc0027I Exiting on user event
# Cbc0005I Partial search - best objective 1e+50 (best possible 6971.1192), took 1174207 iterations and 4683 nodes (656.82 seconds)
# Cbc0032I Strong branching done 39418 times (1024413 iterations), fathomed 147 nodes and fixed 7947 variables
# Cbc0035I Maximum depth 570, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 6502.05 to 6971.12
# Probing was tried 13 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.323 seconds)
# Gomory was tried 1846 times and created 4952 cuts of which 0 were active after adding rounds of cuts (6.283 seconds)
# Knapsack was tried 13 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 13 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# MixedIntegerRounding2 was tried 1846 times and created 44715 cuts of which 0 were active after adding rounds of cuts (5.696 seconds)
# FlowCover was tried 1846 times and created 37452 cuts of which 0 were active after adding rounds of cuts (21.089 seconds)
# TwoMirCuts was tried 1846 times and created 42895 cuts of which 0 were active after adding rounds of cuts (7.163 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
#
# Result - User ctrl-cuser ctrl-c
#
# No feasible solution found
# Lower bound:                    6971.119
# Enumerated nodes:               4683
# Total iterations:               1174207
# Time (CPU seconds):             651.69
# Time (Wallclock seconds):       656.83
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       651.74   (Wallclock seconds):       656.89
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 28
#      26 # 5. Solver with 15-minute time limit (as the problem is NP-Hard)
#      27 solver = pulp.PULP_CBC_CMD(timeLimit=900, msg=1)
# ---> 28 prob.solve(solver)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pulp/pulp.py:2092, in LpProblem.solve(self, solver, **kwargs)
#    2090 # time it
#    2091 self.startClock()
# -> 2092 status = solver.actualSolve(self, **kwargs)
#    2093 self.stopClock()
#    2094 self.restoreObjective(wasNone, dummyVar)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pulp/apis/coin_api.py:144, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     142 def actualSolve(self, lp: LpProblem, **kwargs):
#     143     """Solve a well formulated lp problem"""
# --> 144     return self.solve_CBC(lp, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pulp/apis/coin_api.py:222, in COIN_CMD.solve_CBC(self, lp, use_mps)
#     220 else:
#     221     cbc = subprocess.Popen(args, stdout=pipe, stderr=pipe, stdin=devnull)
# --> 222 if cbc.wait() != 0:
#     223     if pipe:
#     224         pipe.close()
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:1189, in Popen.wait(self, timeout)
#    1187     endtime = _time() + timeout
#    1188 try:
# -> 1189     return self._wait(timeout=timeout)
#    1190 except KeyboardInterrupt:
#    1191     # https://bugs.python.org/issue25942
#    1192     # The first keyboard interrupt waits briefly for the child to
#    1193     # exit under the common assumption that it also received the ^C
#    1194     # generated SIGINT and will exit rapidly.
#    1195     if timeout is not None:
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:1917, in Popen._wait(self, timeout)
#    1915 if self.returncode is not None:
#    1916     break  # Another thread waited.
# -> 1917 (pid, sts) = self._try_wait(0)
#    1918 # Check the pid and loop as waitpid has been known to
#    1919 # return 0 even without WNOHANG in odd situations.
#    1920 # http://bugs.python.org/issue14396.
#    1921 if pid == self.pid:
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py:1875, in Popen._try_wait(self, wait_flags)
#    1873 """All callers to this function MUST hold self._waitpid_lock."""
#    1874 try:
# -> 1875     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1876 except ChildProcessError:
#    1877     # This happens if SIGCLD is set to be ignored or waiting
#    1878     # for child processes has otherwise been disabled for our
#    1879     # process.  This child is dead, we can't get the status.
#    1880     pid = self.pid
#
# KeyboardInterrupt:
