# %% [markdown]
# # CVRP Optimization: Exact Method (ILP)

# %% [markdown]
# ## Linear Programming Formulation (Exact Method)

# %% [markdown]
# To solve the Capacitated Vehicle Routing Problem (CVRP), we implement the Miller-Tucker-Zemlin (MTZ) formulation. This approach ensures that all customers are visited while strictly preventing the formation of isolated "sub-tours" that do not connect to the depot.
#
# * **Decision Variables:**
#   * $x_{ij} \in \{0, 1\}$: Binary variable, 1 if a vehicle travels directly from node $i$ to node $j$, 0 otherwise.
#   * $u_i \in [q_i, Q]$: Auxiliary continuous variable representing the cumulative load carried by the vehicle after visiting node $i$.
# * **Objective Function:**
#   * Minimize $Z = \sum_{i \in N} \sum_{j \in N} c_{ij} x_{ij}$ (Total Euclidean distance across all active routes).
# * **Key Constraints:**
#   * **Flow Balance:** Every customer must have exactly one incoming and one outgoing edge.
#   * **Capacity & Sub-tour Elimination (MTZ):** $u_i - u_j + Q \cdot x_{ij} \le Q - d_j$. This ensures the vehicle capacity $Q$ is never exceeded and prevents disconnected loops.

# %% [markdown]
# ## Data Parsing Component

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/dxdy/Library/Python/3.9/lib/python/site-packages (from scipy) (2.0.2)
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 242.6 kB/s  0:02:05m0:00:0100:04
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
# !pip install pulp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pulp
#   Downloading pulp-3.3.0-py3-none-any.whl.metadata (8.4 kB)
# Downloading pulp-3.3.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 241.9 kB/s  0:01:08m0:00:0100:03
# Installing collected packages: pulp
# Successfully installed pulp-3.3.0
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance_matrix
import pulp

def load_vrp_data(filepath):
    """Parses the .vrp file to extract nodes, demands, and capacity."""
    with open(filepath, 'r') as f:
        lines = f.readlines()

    capacity = int([l for l in lines if "CAPACITY" in l][0].split(":")[1])
    
    # Find start of sections
    coord_start = lines.index("NODE_COORD_SECTION\t\t\n") + 1
    demand_start = lines.index("DEMAND_SECTION\t\t\n") + 1
    dimension = int([l for l in lines if "DIMENSION" in l][0].split(":")[1])

    # Parse Coordinates
    coords = []
    for i in range(coord_start, coord_start + dimension):
        parts = lines[i].split()
        coords.append((float(parts[1]), float(parts[2])))

    # Parse Demands
    demands = []
    for i in range(demand_start, demand_start + dimension):
        demands.append(int(lines[i].split()[1]))

    return np.array(coords), demands, capacity

# Load your specific Kaggle files
all_coords, all_demands, capacity = load_vrp_data('data/X-n101-k25.vrp')

# Select the subset (First 10 nodes for the Exact Method test)
# Always keep the first node (the Depot) and then take a subset of customers
N_SUBSET = 10

# Extract the depot (index 0)
depot_coords = all_coords[0:1]
depot_demand = all_demands[0:1]

# Extract the customers (indices 1 to N_SUBSET)
customer_coords = all_coords[1:N_SUBSET+1]
customer_demands = all_demands[1:N_SUBSET+1]

# Combine them
coords = np.vstack((depot_coords, customer_coords))
demands = depot_demand + customer_demands
N = len(coords)
dist_mat = distance_matrix(coords, coords)

# %% [markdown]
# ## ILP Model Implementation

# %%
# 1. Initialize Problem
prob = pulp.LpProblem("CVRP_Exact_ILP", pulp.LpMinimize)

# 2. Decision Variables
x = pulp.LpVariable.dicts("x", [(i, j) for i in range(N) for j in range(N)], cat='Binary')
u = pulp.LpVariable.dicts("u", range(N), lowBound=0, upBound=capacity)

# 3. Objective Function: Minimize Total Distance
prob += pulp.lpSum(dist_mat[i][j] * x[i, j] for i in range(N) for j in range(N) if i != j)

# 4. Constraints
# Requirement A: Every customer (Nodes 1 to N-1) must be visited exactly once
for i in range(1, N):
    prob += pulp.lpSum(x[j, i] for j in range(N) if i != j) == 1
    prob += pulp.lpSum(x[i, j] for j in range(N) if i != j) == 1

# Requirement B: Depot Flow (Multi-vehicle support)
# We calculate max_vehicles to ensure the total demand (603) can be met
max_vehicles = 5 
prob += pulp.lpSum(x[0, j] for j in range(1, N)) <= max_vehicles
# Every vehicle that leaves the depot must return to the depot
prob += pulp.lpSum(x[0, j] for j in range(1, N)) == pulp.lpSum(x[j, 0] for j in range(1, N))

# Requirement C: MTZ Sub-tour Elimination & Capacity Tracking
for i in range(1, N):
    for j in range(1, N):
        if i != j:
            # If a vehicle travels from i to j, the load must increase by demand[j]
            prob += u[i] - u[j] + capacity * x[i, j] <= capacity - demands[j]

# Every customer's cumulative load must at least be their own demand
for i in range(1, N):
    prob += u[i] >= demands[i]

# 5. Solver with 2-minute time limit (as the problem is NP-Hard)
# Add a 5% gap tolerance to speed up convergence
solver = pulp.PULP_CBC_CMD(timeLimit=120, gapRel=0.05, msg=1)
prob.solve(solver)

print(f"Status: {pulp.LpStatus[prob.status]}")
if prob.status in [1, 0]:
    print(f"Total Distance (Optimized): {pulp.value(prob.objective)}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/dxdy/Library/Python/3.9/lib/python/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/ml/czjfmszj3r3125pzm_gw9mdc0000gn/T/133cd1b034a046e5a34d3ddc1d8cd4e5-pulp.mps -sec 120 -ratio 0.05 -timeMode elapsed -branch -printingOptions all -solution /var/folders/ml/czjfmszj3r3125pzm_gw9mdc0000gn/T/133cd1b034a046e5a34d3ddc1d8cd4e5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 127 COLUMNS
# At line 968 RHS
# At line 1091 BOUNDS
# At line 1212 ENDATA
# Problem MODEL has 122 rows, 120 columns and 510 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 120
# ratioGap was changed from 0 to 0.05
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2161.11 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 90 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 90 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 87 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 87 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 84 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 84 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 84 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 78 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0004I processed model has 112 rows, 120 columns (110 integer (110 of which binary)) and 1190 elements
# Cbc0038I Initial state - 28 integers unsatisfied sum - 7.89982
# Cbc0038I Pass   1: suminf.    5.71192 (27) obj. 3384.57 iterations 58
# Cbc0038I Pass   2: suminf.    4.91683 (20) obj. 3555.5 iterations 14
# Cbc0038I Pass   3: suminf.    3.23847 (13) obj. 5161.99 iterations 47
# Cbc0038I Pass   4: suminf.    2.15091 (9) obj. 5598.11 iterations 17
# Cbc0038I Pass   5: suminf.    0.59786 (6) obj. 5691.98 iterations 17
# Cbc0038I Pass   6: suminf.    0.62222 (4) obj. 5822.38 iterations 25
# Cbc0038I Pass   7: suminf.    0.85922 (3) obj. 5768.71 iterations 17
# Cbc0038I Solution found of 5963.02
# Cbc0038I Relaxing continuous gives 5963.02
# Cbc0038I Before mini branch and bound, 50 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 112 rows 120 columns, reduced to 111 rows 70 columns
# Cbc0038I Mini branch and bound improved solution from 5963.02 to 4633.79 (0.11 seconds)
# Cbc0038I Round again with cutoff of 4406.4
# Cbc0038I Pass   8: suminf.    5.71192 (27) obj. 3384.57 iterations 0
# Cbc0038I Pass   9: suminf.    4.91683 (20) obj. 3555.5 iterations 23
# Cbc0038I Pass  10: suminf.    4.66490 (17) obj. 4406.4 iterations 37
# Cbc0038I Pass  11: suminf.    3.32323 (17) obj. 4406.4 iterations 26
# Cbc0038I Pass  12: suminf.    2.11583 (11) obj. 4406.4 iterations 35
# Cbc0038I Pass  13: suminf.    1.39909 (10) obj. 4406.4 iterations 17
# Cbc0038I Pass  14: suminf.    2.66779 (14) obj. 3455.64 iterations 31
# Cbc0038I Pass  15: suminf.    2.66779 (14) obj. 3455.64 iterations 2
# Cbc0038I Pass  16: suminf.    2.71301 (11) obj. 4406.4 iterations 40
# Cbc0038I Pass  17: suminf.    1.91009 (8) obj. 4406.4 iterations 21
# Cbc0038I Pass  18: suminf.    1.79036 (10) obj. 4406.4 iterations 15
# Cbc0038I Pass  19: suminf.    2.04337 (7) obj. 3723.23 iterations 42
# Cbc0038I Pass  20: suminf.    1.66749 (4) obj. 3721.07 iterations 9
# Cbc0038I Pass  21: suminf.    1.66749 (4) obj. 3721.07 iterations 10
# Cbc0038I Pass  22: suminf.    1.93519 (10) obj. 3738.34 iterations 30
# Cbc0038I Pass  23: suminf.    2.98514 (9) obj. 4406.4 iterations 20
# Cbc0038I Pass  24: suminf.    1.80293 (11) obj. 4139.33 iterations 12
# Cbc0038I Pass  25: suminf.    0.70520 (7) obj. 4406.4 iterations 38
# Cbc0038I Pass  26: suminf.    3.40134 (10) obj. 4406.4 iterations 23
# Cbc0038I Pass  27: suminf.    3.34465 (10) obj. 4406.4 iterations 15
# Cbc0038I Pass  28: suminf.    2.05836 (7) obj. 3764.91 iterations 45
# Cbc0038I Pass  29: suminf.    0.87893 (6) obj. 4406.4 iterations 11
# Cbc0038I Pass  30: suminf.    0.58568 (7) obj. 4406.4 iterations 11
# Cbc0038I Pass  31: suminf.    2.86239 (14) obj. 3663.43 iterations 26
# Cbc0038I Pass  32: suminf.    1.81011 (7) obj. 3744.69 iterations 16
# Cbc0038I Pass  33: suminf.    2.25285 (9) obj. 4406.4 iterations 21
# Cbc0038I Pass  34: suminf.    1.66368 (7) obj. 3902.12 iterations 20
# Cbc0038I Pass  35: suminf.    2.30393 (11) obj. 3817.83 iterations 21
# Cbc0038I Pass  36: suminf.    1.35001 (6) obj. 4406.4 iterations 7
# Cbc0038I Pass  37: suminf.    1.25494 (5) obj. 4406.4 iterations 9
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 36 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 112 rows 120 columns, reduced to 112 rows 84 columns - 7 fixed gives 63, 25 - ok now
# Cbc0038I Full problem 112 rows 120 columns, reduced to 52 rows 24 columns
# Cbc0038I Mini branch and bound did not improve solution (0.13 seconds)
# Cbc0038I After 0.13 seconds - Feasibility pump exiting with objective of 4633.79 - took 0.09 seconds
# Cbc0012I Integer solution of 4633.7888 found by feasibility pump after 0 iterations and 0 nodes (0.13 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 106 rows 41 columns
# Cbc0031I 12 added rows had average density of 69.833333
# Cbc0013I At root node, 12 cuts changed objective from 2359.8808 to 2582.5703 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 246 row cuts average 2.6 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1438 row cuts average 114.9 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 5 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 176 row cuts average 2.5 elements, 0 column cuts (0 active)  in 0.054 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 88 row cuts average 2.1 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 273 row cuts average 54.8 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 4633.7888 best solution, best possible 2582.5703 (0.46 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 102 rows 34 columns
# Cbc0038I Full problem 112 rows 120 columns, reduced to 89 rows 24 columns
# Cbc0016I Integer solution of 4265.1838 found by strong branching after 11331 iterations and 179 nodes (0.97 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 97 rows 35 columns
# Cbc0038I Full problem 112 rows 120 columns, reduced to 79 rows 32 columns
# Cbc0038I Full problem 112 rows 120 columns, reduced to 93 rows 31 columns
# Cbc0016I Integer solution of 4249.2192 found by strong branching after 22656 iterations and 557 nodes (1.80 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 101 rows 38 columns
# Cbc0038I Full problem 112 rows 120 columns, reduced to 96 rows 34 columns
# Cbc0038I Full problem 112 rows 120 columns, reduced to 92 rows 33 columns
# Cbc0010I After 1000 nodes, 18 on tree, 4249.2192 best solution, best possible 2582.5703 (2.41 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 99 rows 38 columns
# Cbc0010I After 2000 nodes, 5 on tree, 4249.2192 best solution, best possible 2582.5703 (3.33 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 100 rows 42 columns
# Cbc0038I Full problem 112 rows 120 columns, reduced to 88 rows 25 columns
# Cbc0010I After 3000 nodes, 26 on tree, 4249.2192 best solution, best possible 2648.3769 (4.25 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 96 rows 38 columns
# Cbc0010I After 4000 nodes, 18 on tree, 4249.2192 best solution, best possible 2648.3769 (4.97 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 103 rows 37 columns
# Cbc0010I After 5000 nodes, 20 on tree, 4249.2192 best solution, best possible 2648.3769 (5.66 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 103 rows 39 columns
# Cbc0010I After 6000 nodes, 18 on tree, 4249.2192 best solution, best possible 2648.3769 (6.33 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 99 rows 39 columns
# Cbc0010I After 7000 nodes, 12 on tree, 4249.2192 best solution, best possible 2648.3769 (6.92 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 102 rows 37 columns
# Cbc0010I After 8000 nodes, 8 on tree, 4249.2192 best solution, best possible 2648.3769 (7.44 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 104 rows 40 columns
# Cbc0038I Full problem 112 rows 120 columns, reduced to 94 rows 33 columns
# Cbc0010I After 9000 nodes, 13 on tree, 4249.2192 best solution, best possible 2648.3769 (8.01 seconds)
# Cbc0038I Full problem 112 rows 120 columns, reduced to 104 rows 42 columns
# Cbc0010I After 10000 nodes, 12 on tree, 4249.2192 best solution, best possible 2648.3769 (8.62 seconds)
# Cbc0010I After 11000 nodes, 10 on tree, 4249.2192 best solution, best possible 2648.3769 (9.17 seconds)
# Cbc0010I After 12000 nodes, 343 on tree, 4249.2192 best solution, best possible 3611.9822 (10.16 seconds)
# Cbc0010I After 13000 nodes, 521 on tree, 4249.2192 best solution, best possible 3835.5213 (10.68 seconds)
# Cbc0010I After 14000 nodes, 342 on tree, 4249.2192 best solution, best possible 3835.5213 (10.99 seconds)
# Cbc0010I After 15000 nodes, 212 on tree, 4249.2192 best solution, best possible 4086.3154 (11.34 seconds)
# Cbc0011I Exiting as integer gap of 162.9038 less than 1e-10 or 5%
# Cbc0001I Search completed - best objective 4249.2191661013, took 528201 iterations and 19601 nodes (11.34 seconds)
# Cbc0032I Strong branching done 25492 times (401244 iterations), fathomed 811 nodes and fixed 1506 variables
# Cbc0041I Maximum depth 40, 30460 variables fixed on reduced cost (complete fathoming 98 times, 4600 nodes taking 62835 iterations)
# Cuts at root node changed objective from 2359.88 to 2582.57
# Probing was tried 6208 times and created 55626 cuts of which 0 were active after adding rounds of cuts (0.648 seconds)
# Gomory was tried 4568 times and created 2115 cuts of which 0 were active after adding rounds of cuts (0.312 seconds)
# Knapsack was tried 100 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 4568 times and created 3736 cuts of which 0 were active after adding rounds of cuts (0.477 seconds)
# FlowCover was tried 4568 times and created 2144 cuts of which 0 were active after adding rounds of cuts (0.654 seconds)
# TwoMirCuts was tried 4568 times and created 2807 cuts of which 0 were active after adding rounds of cuts (0.446 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 1557 times and created 30 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
#
# Result - Optimal solution found (within gap tolerance)
#
# Objective value:                4249.21916610
# Lower bound:                    4086.315
# Gap:                            0.04
# Enumerated nodes:               19601
# Total iterations:               528201
# Time (CPU seconds):             11.28
# Time (Wallclock seconds):       11.35
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       11.28   (Wallclock seconds):       11.35
#
# Status: Optimal
# Total Distance (Optimized): 4249.219166101407

# %%
import matplotlib.pyplot as plt

def plot_cvrp_results(coords, x_vars, title="ILP Optimized Routes"):
    plt.figure(figsize=(8, 8))
    n = len(coords)
    
    # Check if we actually have values to plot
    for i in range(n):
        for j in range(n):
            val = pulp.value(x_vars[i, j])
            # Check for None and only plot if the edge is selected
            if val is not None and val > 0.9:
                plt.arrow(coords[i, 0], coords[i, 1], 
                          coords[j, 0] - coords[i, 0], coords[j, 1] - coords[i, 1], 
                          head_width=5, color='blue', alpha=0.6, length_includes_head=True)

    plt.scatter(coords[1:, 0], coords[1:, 1], c='red', label='Customers')
    plt.scatter(coords[0, 0], coords[0, 1], c='green', marker='s', s=100, label='Depot')
    plt.title(title)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.show()

# Only attempt plotting if a solution exists
if prob.status in [1, 0]: 
    plot_cvrp_results(coords, x, title=f"ILP Result: {N-1} Customers")
else:
    print(f"Solver Status: {pulp.LpStatus[prob.status]}")
    print("Cannot plot: No feasible solution found. Check your constraints or decrease N_SUBSET.")

# %% [markdown]
# While the ILP model successfully finds the global optimum for a 10-node subset, it fails to find a solution for the full 101-node dataset within the 15-minute time limit. This is a practical demonstration of NP-Hardness. The number of constraints in the MTZ formulation grows quadratically ($O(N^2)$), leading to a combinatorial explosion. This justifies the use of Metaheuristics, such as the Genetic Algorithm used by my partner, which can find high-quality solutions for large-scale problems where exact methods fail.
