# %% [markdown]
# # CVRP Optimization: Exact Method (ILP)

# %% [markdown]
# ## Mathematical Formulation

# %% [markdown]
# * **Decision Variables:** * $x_{ij} \in \{0, 1\}$: $1$ if a vehicle travels from node $i$ to $j$.
#   * $u_i$: Auxiliary variable for capacity/sub-tour tracking.
# * **Objective:**
#   * Minimize $Z = \sum_{i} \sum_{j} c_{ij} x_{ij}$ (Total distance).
# * **Constraints:**
#   1. Every customer must be visited exactly once.
#   2. Vehicles must return to the depot.
#   3. **Capacity Constraint:** Total demand on a route $\le$ Vehicle Capacity $Q$.

# %% [markdown]
# ## Data Parsing Component

# %%
# !pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/dxdy/Library/Python/3.9/lib/python/site-packages (from scipy) (2.0.2)
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 242.6 kB/s  0:02:05m0:00:0100:04
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
# !pip install pulp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pulp
#   Downloading pulp-3.3.0-py3-none-any.whl.metadata (8.4 kB)
# Downloading pulp-3.3.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 241.9 kB/s  0:01:08m0:00:0100:03
# Installing collected packages: pulp
# Successfully installed pulp-3.3.0
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance_matrix
import pulp

def load_vrp_data(filepath):
    """Parses the .vrp file to extract nodes, demands, and capacity."""
    with open(filepath, 'r') as f:
        lines = f.readlines()

    capacity = int([l for l in lines if "CAPACITY" in l][0].split(":")[1])
    
    # Find start of sections
    coord_start = lines.index("NODE_COORD_SECTION\t\t\n") + 1
    demand_start = lines.index("DEMAND_SECTION\t\t\n") + 1
    dimension = int([l for l in lines if "DIMENSION" in l][0].split(":")[1])

    # Parse Coordinates
    coords = []
    for i in range(coord_start, coord_start + dimension):
        parts = lines[i].split()
        coords.append((float(parts[1]), float(parts[2])))

    # Parse Demands
    demands = []
    for i in range(demand_start, demand_start + dimension):
        demands.append(int(lines[i].split()[1]))

    return np.array(coords), demands, capacity

# Load your specific Kaggle files
all_coords, all_demands, capacity = load_vrp_data('data/X-n101-k25.vrp')

# Select the subset (First 20 nodes for the Exact Method test)
N_SUBSET = 15
coords = all_coords[:N_SUBSET]
demands = all_demands[:N_SUBSET]
dist_mat = distance_matrix(coords, coords)
N = len(coords)

# %% [markdown]
# ## ILP Model Implementation

# %%
# 1. Initialize Problem
prob = pulp.LpProblem("CVRP_Exact_ILP", pulp.LpMinimize)

# 2. Decision Variables
x = pulp.LpVariable.dicts("x", [(i, j) for i in range(N) for j in range(N)], cat='Binary')
u = pulp.LpVariable.dicts("u", range(N), lowBound=0, upBound=capacity)

# 3. Objective Function: Minimize Total Distance
prob += pulp.lpSum(dist_mat[i][j] * x[i, j] for i in range(N) for j in range(N) if i != j)

# 4. Constraints
for i in range(N):
    # Every customer visited once
    prob += pulp.lpSum(x[j, i] for j in range(N) if i != j) == 1
    prob += pulp.lpSum(x[i, j] for j in range(N) if i != j) == 1

# Sub-tour elimination & Capacity (MTZ Formulation)
for i in range(1, N):
    for j in range(1, N):
        if i != j:
            prob += u[i] - u[j] + capacity * x[i, j] <= capacity - demands[j]

for i in range(1, N):
    prob += u[i] >= demands[i]

# 5. Solver with 2-minute time limit (as the problem is NP-Hard)
solver = pulp.PULP_CBC_CMD(timeLimit=120, gapRel=0.01, msg=1)
prob.solve(solver)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/dxdy/Library/Python/3.9/lib/python/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/ml/czjfmszj3r3125pzm_gw9mdc0000gn/T/5edfdc84e90d471597677a4f0c1d55bf-pulp.mps -sec 900 -timeMode elapsed -branch -printingOptions all -solution /var/folders/ml/czjfmszj3r3125pzm_gw9mdc0000gn/T/5edfdc84e90d471597677a4f0c1d55bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 406 COLUMNS
# At line 3352 RHS
# At line 3754 BOUNDS
# At line 4154 ENDATA
# Problem MODEL has 401 rows, 399 columns and 1805 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 900
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2932.94 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 342 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 342 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 340 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 340 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 340 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 340 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 336 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 335 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 333 strengthened rows, 0 substitutions
# Cgl0004I processed model has 382 rows, 399 columns (380 integer (380 of which binary)) and 4834 elements
# Cbc0038I Initial state - 50 integers unsatisfied sum - 15.3041
# Cbc0038I Pass   1: suminf.   10.31512 (39) obj. 5086.72 iterations 262
# Cbc0038I Pass   2: suminf.    8.51135 (44) obj. 5420.26 iterations 88
# Cbc0038I Pass   3: suminf.    7.94696 (40) obj. 5467.32 iterations 23
# Cbc0038I Pass   4: suminf.    7.89994 (44) obj. 6306.74 iterations 142
# Cbc0038I Pass   5: suminf.    7.02471 (49) obj. 6919.9 iterations 83
# Cbc0038I Pass   6: suminf.    8.10186 (38) obj. 8271.92 iterations 177
# Cbc0038I Pass   7: suminf.    7.11650 (33) obj. 8412.89 iterations 76
# Cbc0038I Pass   8: suminf.    7.80931 (33) obj. 8628.42 iterations 81
# Cbc0038I Pass   9: suminf.    6.61679 (36) obj. 8777.73 iterations 57
# Cbc0038I Pass  10: suminf.    7.57660 (30) obj. 8998.75 iterations 84
# Cbc0038I Pass  11: suminf.    6.90829 (37) obj. 9167.98 iterations 47
# Cbc0038I Pass  12: suminf.    7.69732 (36) obj. 9074.62 iterations 82
# Cbc0038I Pass  13: suminf.    6.78209 (40) obj. 9094.24 iterations 82
# Cbc0038I Pass  14: suminf.    7.70242 (30) obj. 8936.69 iterations 66
# Cbc0038I Pass  15: suminf.    6.51734 (34) obj. 8962.87 iterations 40
# Cbc0038I Pass  16: suminf.    7.99361 (33) obj. 9049.35 iterations 102
# Cbc0038I Pass  17: suminf.    6.72150 (40) obj. 8996.18 iterations 70
# Cbc0038I Pass  18: suminf.    7.44107 (33) obj. 9047.27 iterations 121
# Cbc0038I Pass  19: suminf.    6.80283 (38) obj. 9132.3 iterations 62
# Cbc0038I Pass  20: suminf.    6.74528 (40) obj. 9387.1 iterations 33
# Cbc0038I Pass  21: suminf.    7.77478 (35) obj. 9496.96 iterations 144
# Cbc0038I Pass  22: suminf.    6.58273 (38) obj. 9756.57 iterations 90
# Cbc0038I Pass  23: suminf.    8.15571 (31) obj. 9598.52 iterations 182
# Cbc0038I Pass  24: suminf.    7.20184 (39) obj. 9420.18 iterations 65
# Cbc0038I Pass  25: suminf.    6.95546 (36) obj. 9523.73 iterations 33
# Cbc0038I Pass  26: suminf.    8.09013 (45) obj. 9582.52 iterations 162
# Cbc0038I Pass  27: suminf.    7.56602 (40) obj. 9703.8 iterations 48
# Cbc0038I Pass  28: suminf.    7.36305 (34) obj. 9639.39 iterations 55
# Cbc0038I Pass  29: suminf.    7.07906 (41) obj. 9474.11 iterations 55
# Cbc0038I Pass  30: suminf.    7.96143 (32) obj. 9298.09 iterations 76
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 140 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 382 rows 399 columns, reduced to 382 rows 259 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.29 seconds)
# Cbc0038I Full problem 383 rows 399 columns, reduced to 383 rows 399 columns - too large
# Cbc0038I After 0.31 seconds - Feasibility pump exiting - took 0.09 seconds
# Cbc0031I 25 added rows had average density of 193.2
# Cbc0013I At root node, 25 cuts changed objective from 3115.0947 to 3313.7819 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 641 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.178 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1973 row cuts average 378.4 elements, 0 column cuts (0 active)  in 0.119 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 2.3 elements, 0 column cuts (0 active)  in 0.058 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 361 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.250 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 175 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.089 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 408 row cuts average 128.1 elements, 0 column cuts (0 active)  in 0.075 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 3313.7819 (1.82 seconds)
# Cbc0010I After 1000 nodes, 53 on tree, 1e+50 best solution, best possible 3313.7819 (6.92 seconds)
# Cbc0010I After 2000 nodes, 149 on tree, 1e+50 best solution, best possible 3313.7819 (11.45 seconds)
# Cbc0010I After 3000 nodes, 143 on tree, 1e+50 best solution, best possible 3313.7819 (14.61 seconds)
# Cbc0010I After 4000 nodes, 145 on tree, 1e+50 best solution, best possible 3313.7819 (17.68 seconds)
# Cbc0010I After 5000 nodes, 137 on tree, 1e+50 best solution, best possible 3313.7819 (20.65 seconds)
# Cbc0010I After 6000 nodes, 256 on tree, 1e+50 best solution, best possible 3313.7833 (24.21 seconds)
# Cbc0010I After 7000 nodes, 256 on tree, 1e+50 best solution, best possible 3313.7833 (27.62 seconds)
# Cbc0010I After 8000 nodes, 240 on tree, 1e+50 best solution, best possible 3313.7833 (30.66 seconds)
# Cbc0010I After 9000 nodes, 310 on tree, 1e+50 best solution, best possible 3313.7833 (33.21 seconds)
# Cbc0010I After 10000 nodes, 420 on tree, 1e+50 best solution, best possible 3314.287 (35.42 seconds)
# Cbc0010I After 11000 nodes, 404 on tree, 1e+50 best solution, best possible 3314.287 (37.52 seconds)
# Cbc0010I After 12000 nodes, 865 on tree, 1e+50 best solution, best possible 3605.2845 (41.52 seconds)
# Cbc0010I After 13000 nodes, 1327 on tree, 1e+50 best solution, best possible 3661.9564 (45.21 seconds)
# Cbc0010I After 14000 nodes, 1397 on tree, 1e+50 best solution, best possible 3662.2216 (47.07 seconds)
# Cbc0010I After 15000 nodes, 1377 on tree, 1e+50 best solution, best possible 3662.2216 (49.49 seconds)
# Cbc0010I After 309000 nodes, 2256 on tree, 1e+50 best solution, best possible 3663.2559 (841.45 seconds)
# Cbc0010I After 310000 nodes, 2240 on tree, 1e+50 best solution, best possible 3663.2559 (844.08 seconds)
# Cbc0010I After 311000 nodes, 2248 on tree, 1e+50 best solution, best possible 3663.2559 (846.74 seconds)
# Cbc0010I After 312000 nodes, 2244 on tree, 1e+50 best solution, best possible 3663.2559 (849.46 seconds)
# Cbc0010I After 313000 nodes, 2268 on tree, 1e+50 best solution, best possible 3663.2559 (851.99 seconds)
# Cbc0010I After 314000 nodes, 2252 on tree, 1e+50 best solution, best possible 3663.2559 (854.35 seconds)
# Cbc0010I After 315000 nodes, 2246 on tree, 1e+50 best solution, best possible 3663.2559 (857.00 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 1e+50 (best possible 3663.2559), took 22333692 iterations and 315906 nodes (899.82 seconds)
# Cbc0032I Strong branching done 94094 times (2142525 iterations), fathomed 1269 nodes and fixed 6699 variables
# Cbc0035I Maximum depth 198, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3115.09 to 3313.78
# Probing was tried 125238 times and created 2505603 cuts of which 0 were active after adding rounds of cuts (36.612 seconds)
# Gomory was tried 57007 times and created 5685 cuts of which 0 were active after adding rounds of cuts (10.135 seconds)
# Knapsack was tried 100 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.058 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# MixedIntegerRounding2 was tried 57007 times and created 119528 cuts of which 0 were active after adding rounds of cuts (18.139 seconds)
# FlowCover was tried 57007 times and created 84548 cuts of which 0 were active after adding rounds of cuts (29.419 seconds)
# TwoMirCuts was tried 57007 times and created 59661 cuts of which 0 were active after adding rounds of cuts (13.987 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ImplicationCuts was tried 528 times and created 19 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
#
# Result - Stopped on time limit
#
# No feasible solution found
# Lower bound:                    3663.256
# Enumerated nodes:               315906
# Total iterations:               22333692
# Time (CPU seconds):             856.67
# Time (Wallclock seconds):       899.83
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       856.67   (Wallclock seconds):       899.84
# 0

# %%
import matplotlib.pyplot as plt

def plot_cvrp_results(coords, x_vars, title="CVRP Optimized Routes"):
    plt.figure(figsize=(10, 10))
    n = len(coords)
    
    # 1. Plot the paths (edges) where x[i,j] == 1
    for i in range(n):
        for j in range(n):
            # Check if the path from i to j was selected by the solver
            if pulp.value(x_vars[i, j]) > 0.9:
                plt.arrow(coords[i, 0], coords[i, 1], 
                          coords[j, 0] - coords[i, 0], coords[j, 1] - coords[i, 1], 
                          head_width=10, color='blue', alpha=0.6, length_includes_head=True)

    # 2. Plot the customers (Nodes)
    plt.scatter(coords[1:, 0], coords[1:, 1], c='red', label='Customers', zorder=5)
    
    # 3. Plot the Depot (Node 0)
    plt.scatter(coords[0, 0], coords[0, 1], c='green', marker='s', s=150, label='Depot', zorder=10)

    plt.title(title)
    plt.xlabel("X Coordinate")
    plt.ylabel("Y Coordinate")
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

# Call the function after your solver finishes
if pulp.LpStatus[prob.status] == 'Optimal' or pulp.LpStatus[prob.status] == 'Not Solved':
    plot_cvrp_results(coords, x, title=f"ILP Results for {N_SUBSET} Nodes")
